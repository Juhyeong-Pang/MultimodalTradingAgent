# %%
# import os
# import sys

# from google.colab import drive
# drive.mount('/content/drive')
# base_path = "/content/drive/MyDrive/Colab Notebooks/Quant"
# os.chdir(base_path)

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.callbacks import LambdaCallback, EarlyStopping, ModelCheckpoint

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import regularizers
from tensorflow.keras.layers import Input, Dropout, Dense, Layer, Embedding, Lambda
from keras_hub.layers import PositionEmbedding
from tensorflow.keras.layers import Embedding, MultiHeadAttention, LayerNormalization, GlobalMaxPooling1D, GlobalAveragePooling1D, TextVectorization
from tensorflow.keras.models import Model, Sequential

import yfinance as yf
from config import config

from dataclasses import dataclass
import glob
from pprint import pprint

# %%
device_name = tf.test.gpu_device_name()
print(f"Using : {device_name}")
# Out:
# Using :

# %% [markdown]
# ### Prepare Dataset

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, "[%s]" % re.escape("!#$%&'()*+,-./:;<=>?@\^_`{|}~"), ""
    )

def get_vectorize_layer(texts, vocab_size, max_seq, special_tokens=["[MASK]"]):
    vectorize_layer = TextVectorization(
        max_tokens = vocab_size,
        output_mode = "int",
        standardize = custom_standardization,
        output_sequence_length = max_seq
    )
    vectorize_layer.adapt(texts)

    vocab = vectorize_layer.get_vocabulary()
    vocab = vocab[2: vocab_size - len(special_tokens)] + ["[mask]"]
    vectorize_layer.set_vocabulary(vocab)
    return vectorize_layer

def encode(texts):
    encoded_texts = vectorize_layer(texts)
    return encoded_texts.numpy()

def get_masked_input_and_labels(encoded_texts):
    inp_mask = np.random.rand(*encoded_texts.shape) < 0.15
    inp_mask[encoded_texts <= 2] = False
    labels = -1 * np.ones(encoded_texts.shape, dtype = int)
    labels[inp_mask] = encoded_texts[inp_mask]

    encoded_texts_masked = np.copy(encoded_texts)
    inp_mask_2mask = inp_mask & (np.random.rand(*encoded_texts.shape) < 0.90)
    encoded_texts_masked[inp_mask_2mask] = (mask_token_id)

    inp_mask_2random = inp_mask_2mask & (np.random.rand(*encoded_texts.shape) < 1/9)
    encoded_texts_masked[inp_mask_2random] = np.random.randint(3, mask_token_id, inp_mask_2random.sum())

    sample_weights = np.ones(labels.shape)
    sample_weights[labels == -1] = 0

    y_labels = np.copy(encoded_texts)

    return encoded_texts_masked, y_labels, sample_weights
# Out:
# <>:5: SyntaxWarning: invalid escape sequence '\^'
# <>:5: SyntaxWarning: invalid escape sequence '\^'
# /var/folders/3n/p230j5q16cn1hnmxnb4w3kch0000gn/T/ipykernel_49243/4240608277.py:5: SyntaxWarning: invalid escape sequence '\^'
#   stripped_html, "[%s]" % re.escape("!#$%&'()*+,-./:;<=>?@\^_`{|}~"), ""

# %%
def get_text_list_from_files(files):
    text_list = []
    for name in files:
        with open(name) as f:
            for line in f:
                text_list.append(line)
    return text_list


def get_data_from_text_files(folder_name):
    pos_files = glob.glob("data/aclImdb/" + folder_name + "/pos/*.txt")
    pos_texts = get_text_list_from_files(pos_files)
    neg_files = glob.glob("data/aclImdb/" + folder_name + "/neg/*.txt")
    neg_texts = get_text_list_from_files(neg_files)
    df = pd.DataFrame(
        {
            "review": pos_texts + neg_texts,
            "sentiment": [0] * len(pos_texts) + [1] * len(neg_texts),
        }
    )
    df = df.sample(len(df)).reset_index(drop=True)
    return df


train_df = get_data_from_text_files("train")
test_df = get_data_from_text_files("test")

all_data = pd.concat([train_df, test_df], ignore_index=True)

# %%
all_data
# Out:
#                                                   review  sentiment
# 0      My first attempt at watching this ended in 8 m...          1
# 1      As a Turkish man now living in Sweden I must c...          1
# 2      I think this is a great version, I came on her...          0
# 3      When someone remakes a classic movie, the rema...          1
# 4      The Rookie kept me smiling from beginning to e...          0
# ...                                                  ...        ...
# 49995  Probably the worst movie I have ever seen. It ...          1
# 49996  Wow -- this movie was really bad! You talk abo...          1
# 49997  I saw this movie yesterday on a public service...          1
# 49998  Anyone who knows anything about evolution woul...          1
# 49999  I tend to get furious when hearing about Lucio...          0
#
# [50000 rows x 2 columns]

# %%
vectorize_layer = get_vectorize_layer(
    all_data.review.values.tolist(),
    config.VOCAB_SIZE,
    config.MAX_LEN,
    special_tokens=["[mask]"],
)

# Get mask token id for masked language model
mask_token_id = vectorize_layer(["[mask]"]).numpy()[0][0]

# We have 25000 examples for training
x_train = encode(train_df.review.values)  # encode reviews with vectorizer
y_train = train_df.sentiment.values
train_classifier_ds = (
    tf.data.Dataset.from_tensor_slices((x_train, y_train))
    .shuffle(1000)
    .batch(config.BATCH_SIZE)
)

# We have 25000 examples for testing
x_test = encode(test_df.review.values)
y_test = test_df.sentiment.values
test_classifier_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(
    config.BATCH_SIZE
)

# Dataset for end to end model input (will be used at the end)
test_raw_classifier_ds = test_df

# Prepare data for masked language model
x_all_review = encode(all_data.review.values)
x_masked_train, y_masked_labels, sample_weights = get_masked_input_and_labels(
    x_all_review
)

mlm_ds = tf.data.Dataset.from_tensor_slices(
    (x_masked_train, y_masked_labels, sample_weights)
)
mlm_ds = mlm_ds.shuffle(1000).batch(config.BATCH_SIZE)
mlm_ds_small = mlm_ds.shard(num_shards=8, index=0)

# %%
mlm_ds_small = mlm_ds.shard(num_shards=256, index=0)

# %%
news_raw = pd.read_csv(os.path.join("data", "abcnews-date-text.csv"))
news_text_raw = news_raw["headline_text"]

# %%
# For Local Machine: 

vectorize_layer = get_vectorize_layer(
    news_text_raw.tolist(),
    config.VOCAB_SIZE,
    config.MAX_LEN,
    special_tokens=["[mask]"],
)

mask_token_id = vectorize_layer(["[mask]"]).numpy()[0][0]

x_all_encoded = encode(news_text_raw)

x_masked_train, y_masked_labels, sample_weights = get_masked_input_and_labels(x_all_encoded)

mlm_ds = tf.data.Dataset.from_tensor_slices(
    (x_masked_train, y_masked_labels, sample_weights)
)
mlm_ds = mlm_ds.shuffle(1000).batch(config.BATCH_SIZE)
mlm_ds_small = mlm_ds.shard(num_shards=8, index=0)

# %%
mlm_ds_small = mlm_ds.shard(num_shards=256, index=0)

# %%
# For Google Colab:
# vectorize_layer = get_vectorize_layer(
#     all_data.review.values.tolist(),
#     config.VOCAB_SIZE,
#     config.MAX_LEN,
#     special_tokens=["[mask]"],
# )
# mask_token_id = vectorize_layer(["[mask]"]).numpy()[0][0]

# # mlm_ds was created on a local machine, then added to the drive
# mlm_ds = tf.data.Dataset.load(os.path.join("data", "mlm_dataset_final"))
# mlm_ds_small = mlm_ds.shard(num_shards=32, index=0)

# mlm_ds = mlm_ds.prefetch(tf.data.AUTOTUNE)
# mlm_ds_small = mlm_ds_small.prefetch(tf.data.AUTOTUNE)
# mlm_ds_small = mlm_ds.take(1000).batch(config.BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %%
sentiment_raw = pd.read_csv(os.path.join("data", "sentiment.csv"), encoding='latin1', header = None)
sentiment_raw.columns = ["Output", "Input"]
sentiment_dataset = sentiment_raw[["Input", "Output"]]

df_0 = sentiment_dataset[sentiment_dataset["Output"] == "negative"]
df_1 = sentiment_dataset[sentiment_dataset["Output"] == "neutral"]
df_2 = sentiment_dataset[sentiment_dataset["Output"] == "positive"]

min_label = min(len(df_0), len(df_1), len(df_2))
df_0_downsampled = resample(df_0, replace=False, n_samples=min_label, random_state=42)
df_1_downsampled = resample(df_1, replace=False, n_samples=min_label, random_state=42)
df_2_downsampled = resample(df_2, replace=False, n_samples=min_label, random_state=42)

sentiment_dataset_balanced = pd.concat([df_0_downsampled, df_1_downsampled, df_2_downsampled])

X, y = sentiment_dataset_balanced['Input'], sentiment_dataset_balanced['Output']
X_encoded = encode(X)

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y_encoded, test_size=0.1, random_state=42
)

train_classifier_ds = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(1000)
    .batch(8)
)

test_classifier_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(
    8
)

# %%
print(train_classifier_ds)
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 32), dtype=tf.int64, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %% [markdown]
# ### Create MLM Model & BERT
#
# ``mlm_ds`` : dataset for MLM
#
# ``X_train``, ``y_train``, ``X_test``, ``y_test`` : dataset for Training & Validation

# %%
# Define Classes for the BERT model

class MultiHeadSelfAttention(Layer):
    def __init__(self, embed_dim, num_heads=8, name=None):
        super(MultiHeadSelfAttention, self).__init__(name=name)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.projection_dim = embed_dim // num_heads
        self.query_dense = Dense(embed_dim)
        self.key_dense = Dense(embed_dim)
        self.value_dense = Dense(embed_dim)
        self.combine_heads = Dense(embed_dim)
        self.supports_masking = True

    def attention(self, query, key, value, mask=None):
        score = tf.matmul(query, key, transpose_b=True)
        dim_key = tf.cast(tf.shape(key)[-1], tf.float32)
        scaled_score = score / tf.math.sqrt(dim_key)
        if mask is not None:
            mask = tf.cast(mask, dtype=scaled_score.dtype)
            mask = mask[:, tf.newaxis, tf.newaxis, :]
            scaled_score += (1.0 - mask) * -1e9
        weights = tf.nn.softmax(scaled_score, axis=-1)
        output = tf.matmul(weights, value)
        return output, weights

    def split_heads(self, x, batch_size):
        x = tf.reshape(x, (batch_size, -1, self.num_heads, self.projection_dim))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def call(self, inputs, mask=None):
        batch_size = tf.shape(inputs)[0]
        query = self.query_dense(inputs)
        key = self.key_dense(inputs)
        value = self.value_dense(inputs)
        query = self.split_heads(query, batch_size)
        key = self.split_heads(key, batch_size)
        value = self.split_heads(value, batch_size)
        attention, _ = self.attention(query, key, value, mask=mask)
        attention = tf.transpose(attention, perm=[0, 2, 1, 3])
        concat_attention = tf.reshape(attention, (batch_size, -1, self.embed_dim))
        output = self.combine_heads(concat_attention)
        return output

    def compute_mask(self, inputs, mask=None):
        return mask

class TransformerBlock(Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1, name=None):
        super(TransformerBlock, self).__init__(name=name)
        self.att = MultiHeadSelfAttention(embed_dim, num_heads)
        self.ffn = tf.keras.Sequential([
            Dense(ff_dim, activation="relu"),
            Dense(embed_dim),
        ])
        self.layernorm1 = LayerNormalization(epsilon=1e-6)
        self.layernorm2 = LayerNormalization(epsilon=1e-6)
        self.dropout1 = Dropout(rate)
        self.dropout2 = Dropout(rate)
        self.supports_masking = True

    def call(self, inputs, training=False, mask=None):
        # Attention Layer + Dropout
        attn_output = self.att(inputs, mask=mask)
        attn_output = self.dropout1(attn_output, training=training)
        # Residual Connection + Normalization
        out1 = self.layernorm1(inputs + attn_output)
        # Feed Forward + Dropout
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        # Residual Connection + Final Normalization and Return
        return self.layernorm2(out1 + ffn_output)

    def compute_mask(self, inputs, mask=None):
        return mask

class TransformerEncoder(Layer):
    def __init__(self, num_layers, embed_dim, num_heads, ff_dim, rate=0.1, name="transformer_encoder", **kwargs):
       
        super(TransformerEncoder, self).__init__(name=name, **kwargs)
        self.num_layers = num_layers
        self.embed_dim = embed_dim
        self.enc_layers = [TransformerBlock(embed_dim, num_heads, ff_dim, rate, name=f"Transformer_Block_{i}") for i in range(num_layers)]
        self.dropout = Dropout(rate)
        self.supports_masking = True

    def call(self, inputs, training=False, mask=None):
        x = inputs
        for i in range(self.num_layers):
            x = self.enc_layers[i](x, training=training, mask=mask)
        return x

    def compute_mask(self, inputs, mask=None):
        return mask

# %%
# Class for MLM

loss_fn = keras.losses.SparseCategoricalCrossentropy(reduction=None)
loss_tracker = keras.metrics.Mean(name="loss")

class MaskedLanguageModel(keras.Model):
    def compute_loss(self, x=None, y=None, y_pred=None, sample_weight=None):

        loss = loss_fn(y, y_pred, sample_weight)
        loss_tracker.update_state(loss, sample_weight=sample_weight)
        return keras.ops.sum(loss)

    def compute_metrics(self, x, y, y_pred, sample_weight):
        return {"loss": loss_tracker.result()}

    @property
    def metrics(self):
        return [loss_tracker]

# %%
def create_masked_language_bert_model():
    input_layer = Input(shape=(config.MAX_LEN,), dtype="int64")
    word_embeddings = Embedding(
        input_dim=config.VOCAB_SIZE, 
        output_dim=config.EMBED_DIM, 
    )(input_layer)
    position_embeddings = PositionEmbedding(
        sequence_length=config.MAX_LEN
    )(word_embeddings)
    embeddings = word_embeddings + position_embeddings

    encoder_layer = TransformerEncoder(config.NUM_LAYERS, config.EMBED_DIM, config.NUM_HEAD, config.FF_DIM)
    encoder_output = encoder_layer(embeddings)
    
    mlm_output = Dense(config.VOCAB_SIZE, name="mlm_cls", activation="softmax")(encoder_output)
    
    mlm_model = MaskedLanguageModel(input_layer, mlm_output, name="masked_bert_model")

    optimizer = keras.optimizers.Adam(learning_rate=config.LR)
    mlm_model.compile(optimizer=optimizer)
    return mlm_model

# %% [markdown]
# ### Train MLM Model

# %%
class MaskedTextGenerator(keras.callbacks.Callback):
    def __init__(self, sample_tokens, top_k=5):
        self.sample_tokens = sample_tokens
        self.k = top_k

    def decode(self, tokens):
        return " ".join([
            id2token.get(int(t), "[UNK]")
            for t in tokens if t != 0
        ])

    def convert_ids_to_tokens(self, id):
        return id2token[id]

    def on_epoch_end(self, epoch, logs=None):
        prediction = self.model.predict(self.sample_tokens)

        masked_index = np.where(self.sample_tokens == mask_token_id)
        masked_index = masked_index[1]
        mask_prediction = prediction[0][masked_index]

        top_indices = mask_prediction[0].argsort()[-self.k :][::-1]
        values = mask_prediction[0][top_indices]

        for i in range(len(top_indices)):
            p = top_indices[i]
            v = values[i]
            tokens = np.copy(sample_tokens[0])
            tokens[masked_index[0]] = p
            result = {
                "input_text": self.decode(sample_tokens[0].numpy()),
                "prediction": self.decode(tokens),
                "probability": v,
                "predicted mask token": self.convert_ids_to_tokens(p),
            }
            pprint(result)

def save_model_weights(model, file_name, folder_name):
    os.makedirs(folder_name, exist_ok=True)

    words = file_name.split(".")

    model_name = words[0]

    existing_files = [f for f in os.listdir(folder_name) if f.startswith(model_name)]
    next_number = len(existing_files) + 1
    words[0] = f"{model_name}_{next_number}"

    file_name = ".".join(words)
    save_path = os.path.join(folder_name, file_name)

    model.save_weights(save_path)
    print(f"model saved to: {save_path}")

# %%
id2token = dict(enumerate(vectorize_layer.get_vocabulary()))
token2id = {y: x for x, y in id2token.items()}

sample_tokens = vectorize_layer(["I have watched this [mask] and it was awesome"])
generator_callback = MaskedTextGenerator(sample_tokens.numpy())
checkpoint_callback = ModelCheckpoint(
    os.path.join("models", "model_weights_cp_best.weights.h5"), 
    save_best_only=True,
    monitor="loss",
    save_weights_only=True,
    mode="min",
    verbose=1
)

# %%
sample_tokens = vectorize_layer(["I have watched this [mask] and it was awesome"])
generator_callback = MaskedTextGenerator(sample_tokens.numpy())

bert_masked_model = create_masked_language_bert_model()
bert_masked_model.summary()
# Out:
# Model: "masked_bert_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 12)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 12, 128)   │  3,840,000 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ position_embedding  │ (None, 12, 128)   │      1,536 │ embedding[0][0]   │
# │ (PositionEmbedding) │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 12, 128)   │          0 │ embedding[0][0],  │
# │                     │                   │            │ position_embeddi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_encoder │ (None, 12, 128)   │    398,336 │ add[0][0]         │
# │ (TransformerEncode… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mlm_cls (Dense)     │ (None, 12, 30000) │  3,870,000 │ transformer_enco… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,109,872 (30.94 MB)
#  Trainable params: 8,109,872 (30.94 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
print("model vocab size:", bert_masked_model.output_shape[-1])
print("id2token size:", id2token[2])
# Out:
# model vocab size: 30000
# id2token size: to

# %%
bert_masked_model.fit(mlm_ds_small, epochs=15, callbacks=[generator_callback, checkpoint_callback])
save_model_weights(bert_masked_model, "bert_masked_model_len32.weights.h5", "models")
# Out:
# Epoch 1/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.009691644)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.009594017)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.007687918)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.007202337)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('a'),
#  'prediction': 'i have watched this a and it was awesome',
#  'probability': np.float32(0.0043075103)}
#
# Epoch 1: loss improved from None to 9.40143, saving model to models/model_weights_cp_best.weights.h5
#
# Epoch 1: finished saving model to models/model_weights_cp_best.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 28s 149ms/step - loss: 9.4014
# Epoch 2/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.014304432)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.010216908)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.008859783)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('and'),
#  'prediction': 'i have watched this and and it was awesome',
#  'probability': np.float32(0.0071524703)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.00631748)}
#
# Epoch 2: loss improved from 9.40143 to 8.89970, saving model to models/model_weights_cp_best.weights.h5
#
# Epoch 2: finished saving model to models/model_weights_cp_best.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 146ms/step - loss: 8.8997
# Epoch 3/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.01901628)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.014750345)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.008989729)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.0082413815)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.0076278145)}
#
# Epoch 3: loss improved from 8.89970 to 8.80040, saving model to models/model_weights_cp_best.weights.h5
#
# Epoch 3: finished saving model to models/model_weights_cp_best.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 23s 151ms/step - loss: 8.8004
# Epoch 4/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.01944716)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.018688507)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.011563109)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.009723177)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.009007111)}
#
# Epoch 4: loss improved from 8.80040 to 8.74796, saving model to models/model_weights_cp_best.weights.h5
#
# Epoch 4: finished saving model to models/model_weights_cp_best.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - loss: 8.7480
# Epoch 5/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.0125633795)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.0113378)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.0108701615)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.00848933)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.007566161)}
#
# Epoch 5: loss did not improve from 8.74796
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 145ms/step - loss: 8.7675
# Epoch 6/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.02275523)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.014271424)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.014239173)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.009839366)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.009448751)}
#
# Epoch 6: loss improved from 8.74796 to 8.62136, saving model to models/model_weights_cp_best.weights.h5
#
# Epoch 6: finished saving model to models/model_weights_cp_best.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 24s 155ms/step - loss: 8.6214
# Epoch 7/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.027454903)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.019918451)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.017695341)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.01325083)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.008695708)}
#
# Epoch 7: loss improved from 8.62136 to 8.60196, saving model to models/model_weights_cp_best.weights.h5
#
# Epoch 7: finished saving model to models/model_weights_cp_best.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 22s 148ms/step - loss: 8.6020
# Epoch 8/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.020778406)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.019003691)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.016886124)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.014487997)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.013867921)}
#
# Epoch 8: loss improved from 8.60196 to 8.54858, saving model to models/model_weights_cp_best.weights.h5
#
# Epoch 8: finished saving model to models/model_weights_cp_best.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 27s 176ms/step - loss: 8.5486
# Epoch 9/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.021300834)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.01936969)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.01179041)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.011485882)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.009817492)}
#
# Epoch 9: loss did not improve from 8.54858
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 26s 171ms/step - loss: 8.5524
# Epoch 10/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.017457522)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.013678761)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.011707858)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.009188618)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.0085292235)}
#
# Epoch 10: loss did not improve from 8.54858
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 25s 165ms/step - loss: 8.5774
# Epoch 11/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.016068617)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.013372287)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.009126059)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.0078922175)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.0075667896)}
#
# Epoch 11: loss improved from 8.54858 to 8.54260, saving model to models/model_weights_cp_best.weights.h5
#
# Epoch 11: finished saving model to models/model_weights_cp_best.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 29s 188ms/step - loss: 8.5426
# Epoch 12/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.007270992)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.005366887)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.0049989764)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.0045444868)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.0035060246)}
#
# Epoch 12: loss improved from 8.54260 to 8.48733, saving model to models/model_weights_cp_best.weights.h5
#
# Epoch 12: finished saving model to models/model_weights_cp_best.weights.h5
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 29s 187ms/step - loss: 8.4873
# Epoch 13/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.01014575)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.0087521635)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.008305268)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.0061361846)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.0045254184)}
#
# Epoch 13: loss did not improve from 8.48733
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 26s 170ms/step - loss: 8.5773
# Epoch 14/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.0138324145)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.011221127)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.010632038)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.00886683)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.007347878)}
#
# Epoch 14: loss did not improve from 8.48733
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 26s 173ms/step - loss: 8.5252
# Epoch 15/15
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('in'),
#  'prediction': 'i have watched this in and it was awesome',
#  'probability': np.float32(0.015887259)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('for'),
#  'prediction': 'i have watched this for and it was awesome',
#  'probability': np.float32(0.011549901)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('of'),
#  'prediction': 'i have watched this of and it was awesome',
#  'probability': np.float32(0.009036554)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('on'),
#  'prediction': 'i have watched this on and it was awesome',
#  'probability': np.float32(0.0079535805)}
# {'input_text': 'i have watched this [mask] and it was awesome',
#  'predicted mask token': np.str_('the'),
#  'prediction': 'i have watched this the and it was awesome',
#  'probability': np.float32(0.00584058)}
#
# Epoch 15: loss did not improve from 8.48733
# 152/152 ━━━━━━━━━━━━━━━━━━━━ 31s 203ms/step - loss: 8.4968
# model saved to: models/bert_masked_model_len32_2.weights.h5

# %%
# bert_masked_model.load_weights("models/bert_masked_model_1.weights.h5")

# %%
print(bert_masked_model)
# Out:
# <MaskedLanguageModel name=masked_bert_model, built=True>

# %%
pretrained_bert_model = keras.Model(
    bert_masked_model.input, bert_masked_model.get_layer("transformer_encoder").output
)

# %%
pretrained_bert_model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 12)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding           │ (None, 12, 128)   │  3,840,000 │ input_layer[0][0] │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ position_embedding  │ (None, 12, 128)   │      1,536 │ embedding[0][0]   │
# │ (PositionEmbedding) │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 12, 128)   │          0 │ embedding[0][0],  │
# │                     │                   │            │ position_embeddi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ transformer_encoder │ (None, 12, 128)   │    398,336 │ add[0][0]         │
# │ (TransformerEncode… │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,239,872 (16.17 MB)
#  Trainable params: 4,239,872 (16.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def create_classifier_bert_model():
    inputs = Input(shape=(config.MAX_LEN,), dtype="int64")
    sequence_output = pretrained_bert_model(inputs)
    cls_token = sequence_output[:, 0, :] 
    hidden_layer = Dense(64, activation="relu")(cls_token)
    hidden_layer = Dropout(0.2)(hidden_layer)
    hidden_layer = Dense(32, activation="relu")(hidden_layer)
    hidden_layer = Dropout(0.2)(hidden_layer)
    hidden_layer = Dense(16, activation="relu")(hidden_layer)
    hidden_layer = Dropout(0.2)(hidden_layer)
    outputs = Dense(3, activation="softmax")(hidden_layer)
    classifer_model = keras.Model(inputs, outputs, name="classification")
    
    optimizer = keras.optimizers.Adam()
    classifer_model.compile(
        optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"]
    )
    return classifer_model

# %%
pretrained_bert_model.trainable = False
classifer_model = create_classifier_bert_model()
classifer_model.summary()
# Out:
# Model: "classification"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_6 (InputLayer)      │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_4 (Functional)       │ (None, 12, 128)        │     4,239,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ get_item (GetItem)              │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 3)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,250,787 (16.22 MB)
#  Trainable params: 10,915 (42.64 KB)
#  Non-trainable params: 4,239,872 (16.17 MB)

# %%
# Train the classifier with frozen BERT stage
classifer_model.fit(
    train_classifier_ds,
    epochs=5,
    validation_data=test_classifier_ds,
)
save_model_weights(classifer_model, "classifer_model_freeze.weights.h5", "models")
# Out:
# Epoch 1/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.3215 - loss: 1.1077 - val_accuracy: 0.4121 - val_loss: 1.0945
# Epoch 2/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3233 - loss: 1.1039 - val_accuracy: 0.2418 - val_loss: 1.0999
# Epoch 3/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3509 - loss: 1.0993 - val_accuracy: 0.4121 - val_loss: 1.0986
# Epoch 4/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3399 - loss: 1.0994 - val_accuracy: 0.2418 - val_loss: 1.1068
# Epoch 5/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3313 - loss: 1.0993 - val_accuracy: 0.2418 - val_loss: 1.1047
# model saved to: models/classifer_model_freeze_7.weights.h5

# %%
# Unfreeze the BERT model for fine-tuning
pretrained_bert_model.trainable = True
optimizer = keras.optimizers.Adam()
classifer_model.compile(
    optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)
classifer_model.fit(
    train_classifier_ds,
    epochs=5,
    validation_data=test_classifier_ds,
)
save_model_weights(classifer_model, "classifer_model.weights.h5", "models")
# Out:
# Epoch 1/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.3387 - loss: 1.1009 - val_accuracy: 0.3462 - val_loss: 1.1010
# Epoch 2/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.3411 - loss: 1.1006 - val_accuracy: 0.2418 - val_loss: 1.1192
# Epoch 3/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.3252 - loss: 1.1013 - val_accuracy: 0.2418 - val_loss: 1.1082
# Epoch 4/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - accuracy: 0.3491 - loss: 1.1000 - val_accuracy: 0.2418 - val_loss: 1.1042
# Epoch 5/5
# 204/204 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.3411 - loss: 1.0992 - val_accuracy: 0.2418 - val_loss: 1.1037
# model saved to: models/classifer_model_10.weights.h5

# %%
def predict(text, model):
    text_encoded = encode(text)
    print("Encoded Text: ", text_encoded)
    
    pred = model(text_encoded, training=False)

    probabilities = tf.nn.softmax(pred, axis=-1).numpy()[0]

    pred_class = np.argmax(probabilities)
    sentiment = le.inverse_transform([pred_class])[0]
    confidence_score = probabilities[pred_class]

    class_names = le.classes_
    all_probs = {class_names[i]: float(probabilities[i]) for i in range(len(class_names))}
    
    return sentiment, confidence_score, all_probs

def predict_and_print(text, model):
    new_texts = [text]
    result, confidence, all_probs = predict(new_texts, model)
    
    print(f"Input Headline: \"{text}\"")
    print(f"Top Prediction: {result} ({confidence * 100:.2f}%)")
    print("-" * 30)
    print("Class Probabilities:")
    
    sorted_probs = sorted(all_probs.items(), key=lambda item: item[1], reverse=True)
    
    for label, prob in sorted_probs:
        bar = "#" * int(prob * 20) 
        print(f" - {label:<12}: {prob * 100:>6.2f}% {bar}")

# %%
predict_and_print("This is a negative sign for apple", classifer_model)
# Out:
# Encoded Text:  [[ 873   50   14 3465  711    4 1879    0    0    0    0    0]]
# Input Headline: "This is a negative sign for apple"
# Top Prediction: neutral (33.70%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  33.70% ######
#  - positive    :  33.20% ######
#  - negative    :  33.09% ######
