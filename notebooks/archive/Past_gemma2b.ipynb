# %%
import os

import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk

import tensorflow as tf
from tensorflow import keras
import keras_hub
import json

# %%
gemma_lm = keras_hub.models.GemmaCausalLM.from_preset(
    "./gemma_model",
    dtype="float16"
)
# Out:
# normalizer.cc(51) LOG(INFO) precompiled_charsmap is empty. use identity normalization.

# %%
template = "Instruction:\n{instruction}\n\nInput:{input_str}\n\nResponse:\n{response}"
instruction = """
You are a friendly model that answers user's questions kindly
"""
input_str = "How is the reputation of UW Madison in South Korea?"

prompt = template.format(
    instruction = instruction,
    input_str = input_str,
    response = ""
)

print("Start generating answer...")
output = gemma_lm.generate(
    prompt, 
    max_length = 20,
    stop_token_ids="auto",
    strip_prompt=True,
)
print(output)
# Out:
# Start generating answer...

# %%
help(gemma_lm.generate)
# Out:
# Help on method generate in module keras_hub.src.models.causal_lm:
#
# generate(inputs, max_length=None, stop_token_ids='auto', strip_prompt=False) method of keras_hub.src.models.gemma.gemma_causal_lm.GemmaCausalLM instance
#     Generate text given prompt `inputs`.
#
#     This method generates text based on given `inputs`. The sampling method
#     used for generation can be set via the `compile()` method.
#
#     If `inputs` are a `tf.data.Dataset`, outputs will be generated
#     "batch-by-batch" and concatenated. Otherwise, all inputs will be handled
#     as a single batch.
#
#     If a `preprocessor` is attached to the model, `inputs` will be
#     preprocessed inside the `generate()` function and should match the
#     structure expected by the `preprocessor` layer (usually raw strings).
#     If a `preprocessor` is not attached, inputs should match the structure
#     expected by the `backbone`. See the example usage above for a
#     demonstration of each.
#
#     Args:
# ...
