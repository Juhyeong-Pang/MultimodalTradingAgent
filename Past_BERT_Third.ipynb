# %%
import os
import warnings

# from google.colab import drive
# drive.mount('/content/drive')
# base_path = "/content/drive/MyDrive/Colab Notebooks/Quant"
# os.chdir(base_path)

import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.callbacks import LambdaCallback, EarlyStopping, ModelCheckpoint

import tensorflow as tf

from tensorflow import keras
import keras_hub
from tensorflow.keras import regularizers, layers
from tensorflow.keras.layers import Input, Dropout, Dense, Layer, Embedding, Lambda
from keras_hub.layers import PositionEmbedding
from tensorflow.keras.layers import Embedding, MultiHeadAttention, LayerNormalization, GlobalMaxPooling1D, GlobalAveragePooling1D, TextVectorization, BatchNormalization
from tensorflow.keras.models import Model, Sequential

import yfinance as yf
from config import config

from dataclasses import dataclass
import glob
from pprint import pprint
import nlpaug.augmenter.word as naw
from pygooglenews import GoogleNews

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
warnings.filterwarnings("ignore", category=UserWarning, module="keras")

# %%
def custom_standardization(input_data):
    lowercase = tf.strings.lower(input_data)
    stripped_html = tf.strings.regex_replace(lowercase, "<br />", " ")
    return tf.strings.regex_replace(
        stripped_html, "[%s]" % re.escape("!#$%&'()*+,-./:;<=>?@\\^_`{|}~"), ""
    )

def get_vectorize_layer(texts, vocab_size, max_seq, special_tokens=["[MASK]"]):
    vectorize_layer = TextVectorization(
        max_tokens = vocab_size,
        output_mode = "int",
        standardize = custom_standardization,
        output_sequence_length = max_seq
    )
    vectorize_layer.adapt(texts)

    vocab = vectorize_layer.get_vocabulary()
    vocab = vocab[2: vocab_size - len(special_tokens)] + ["[mask]"]
    vectorize_layer.set_vocabulary(vocab)
    return vectorize_layer

def encode(texts):
    encoded_texts = vectorize_layer(texts)
    return encoded_texts.numpy()

def get_masked_input_and_labels(encoded_texts):
    inp_mask = np.random.rand(*encoded_texts.shape) < 0.15
    inp_mask[encoded_texts <= 2] = False
    labels = -1 * np.ones(encoded_texts.shape, dtype = int)
    labels[inp_mask] = encoded_texts[inp_mask]

    encoded_texts_masked = np.copy(encoded_texts)
    inp_mask_2mask = inp_mask & (np.random.rand(*encoded_texts.shape) < 0.90)
    encoded_texts_masked[inp_mask_2mask] = (mask_token_id)

    inp_mask_2random = inp_mask_2mask & (np.random.rand(*encoded_texts.shape) < 1/9)
    encoded_texts_masked[inp_mask_2random] = np.random.randint(3, mask_token_id, inp_mask_2random.sum())

    sample_weights = np.ones(labels.shape)
    sample_weights[labels == -1] = 0

    y_labels = np.copy(encoded_texts)

    return encoded_texts_masked, y_labels, sample_weights

# %%
# # Dataset for MLM Pretraining For Google Colab:
# news_raw = pd.read_csv(os.path.join("data", "abcnews-date-text.csv"))
# news_text_raw = news_raw["headline_text"]

# vectorize_layer = get_vectorize_layer(
#     news_text_raw.tolist(),
#     config.VOCAB_SIZE,
#     config.MAX_LEN,
#     special_tokens=["[mask]"],
# )
# mask_token_id = vectorize_layer(["[mask]"]).numpy()[0][0]

# # mlm_ds was created on a local machine, then added to the drive
# mlm_ds = tf.data.Dataset.load(os.path.join("data", "mlm_dataset_final"))
# mlm_ds_small = mlm_ds.shard(num_shards=12, index=0)

# # Dataset For Sentiment Classification
# sentiment_raw = pd.read_csv(os.path.join("data", "sentiment.csv"), encoding='latin1', header = None)
# sentiment_raw.columns = ["Output", "Input"]
# sentiment_dataset = sentiment_raw[["Input", "Output"]]

# df_0 = sentiment_dataset[sentiment_dataset["Output"] == "negative"]
# df_1 = sentiment_dataset[sentiment_dataset["Output"] == "neutral"]
# df_2 = sentiment_dataset[sentiment_dataset["Output"] == "positive"]

# min_label = min(len(df_0), len(df_1), len(df_2))
# df_0_downsampled = resample(df_0, replace=False, n_samples=min_label, random_state=42)
# df_1_downsampled = resample(df_1, replace=False, n_samples=min_label, random_state=42)
# df_2_downsampled = resample(df_2, replace=False, n_samples=min_label, random_state=42)

# sentiment_dataset_balanced = pd.concat([df_0_downsampled, df_1_downsampled, df_2_downsampled])

# X, y = sentiment_dataset_balanced['Input'], sentiment_dataset_balanced['Output']
# X_encoded = encode(X)

# le = LabelEncoder()
# y_encoded = le.fit_transform(y)

# X_train, X_test, y_train, y_test = train_test_split(
#     X_encoded, y_encoded, test_size=0.1, random_state=42
# )

# train_classifier_ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train)).shuffle(1000).batch(config.BATCH_SIZE))
# test_classifier_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(config.BATCH_SIZE)

# %%
# Dataset for MLM Pretraining For Local Machine
news_raw = pd.read_csv(os.path.join("data", "abcnews-date-text.csv"))
news_text_raw = news_raw["headline_text"]

vectorize_layer = get_vectorize_layer(
    news_text_raw.tolist(),
    config.VOCAB_SIZE,
    config.MAX_LEN,
    special_tokens=["[mask]"],
)

mask_token_id = vectorize_layer(["[mask]"]).numpy()[0][0]

x_all_encoded = encode(news_text_raw)

x_masked_train, y_masked_labels, sample_weights = get_masked_input_and_labels(x_all_encoded)

mlm_ds = tf.data.Dataset.from_tensor_slices(
    (x_masked_train, y_masked_labels, sample_weights)
)
mlm_ds = mlm_ds.shuffle(1000).batch(config.BATCH_SIZE)
mlm_ds_small = mlm_ds.shard(num_shards=256, index=0)

# %%
import nltk

nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger_eng') # 에러 메시지에서 요구한 파일
nltk.download('punkt_tab') # 문장 토큰화를 위해 가끔 요구됨
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/juhyeongpang/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/juhyeongpang/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /Users/juhyeongpang/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/juhyeongpang/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# 1. 데이터 로드 및 전처리
sentiment_raw = pd.read_csv(os.path.join("data", "sentiment.csv"), encoding='latin1', header=None)
sentiment_raw.columns = ["Output", "Input"]

# 클래스별 분리
df_neg = sentiment_raw[sentiment_raw["Output"] == "negative"]
df_neu = sentiment_raw[sentiment_raw["Output"] == "neutral"]
df_pos = sentiment_raw[sentiment_raw["Output"] == "positive"]

# 2. 다운샘플링 (최소 개수에 맞춤)
min_label = min(len(df_neg), len(df_neu), len(df_pos))
df_neg_down = resample(df_neg, replace=False, n_samples=min_label, random_state=42)
df_neu_down = resample(df_neu, replace=False, n_samples=min_label, random_state=42)
df_pos_down = resample(df_pos, replace=False, n_samples=min_label, random_state=42)

# 3. nlpaug 증강 설정
aug = naw.SynonymAug(aug_src='wordnet')

def augment_text(df, target_count):
    current_count = len(df)
    if current_count >= target_count:
        return df
    
    aug_samples = []
    needed = target_count - current_count
    label_name = df.iloc[0]['Output']
    print(f"Augmenting '{label_name}' class: {current_count} -> {target_count}...")
    
    while len(aug_samples) < needed:
        for text in df['Input']:
            if len(aug_samples) >= needed:
                break
            # 증강 실행
            augmented_text = aug.augment(text)[0]
            aug_samples.append(augmented_text)
            
    df_aug = pd.DataFrame({'Input': aug_samples, 'Output': [label_name] * len(aug_samples)})
    return pd.concat([df, df_aug])

# 4. 600개 -> 2000개로 뻥튀기
target_n = 2000 
df_neg_final = augment_text(df_neg_down, target_n)
df_neu_final = augment_text(df_neu_down, target_n)
df_pos_final = augment_text(df_pos_down, target_n)

# 5. 합치기 및 셔플
final_df = pd.concat([df_neg_final, df_neu_final, df_pos_final]).sample(frac=1, random_state=42).reset_index(drop=True)

# 6. 인코딩 및 데이터셋 생성
# 주의: encode 함수는 본인의 환경에 정의되어 있어야 합니다.
X_encoded = encode(final_df['Input']) 

le = LabelEncoder()
y_encoded = le.fit_transform(final_df['Output'])

X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y_encoded, test_size=0.1, random_state=42
)

# TF 데이터셋 구성
train_classifier_ds = (tf.data.Dataset.from_tensor_slices((X_train, y_train))
                       .shuffle(len(X_train))
                       .batch(32)) # BATCH_SIZE는 상황에 맞게 조절

test_classifier_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(32)

print("Done! 데이터 준비가 완료되었습니다.")
# Out:
# Augmenting 'negative' class: 604 -> 2000...
# Augmenting 'neutral' class: 604 -> 2000...
# Augmenting 'positive' class: 604 -> 2000...
# Done! 데이터 준비가 완료되었습니다.

# %%
mlm_ds_small.element_spec
# Out:
# (TensorSpec(shape=(None, 16), dtype=tf.int64, name=None),
#  TensorSpec(shape=(None, 16), dtype=tf.int64, name=None),
#  TensorSpec(shape=(None, 16), dtype=tf.float64, name=None))

# %%
def bert_module(query, key, value, i, mask=None):
    # Multi headed self-attention
    attention_output = layers.MultiHeadAttention(
        num_heads=config.NUM_HEAD,
        key_dim=config.EMBED_DIM // config.NUM_HEAD,
        name="encoder_{}_multiheadattention".format(i),
    )(query, key, value, attention_mask=mask)
    attention_output = layers.Dropout(0.1, name="encoder_{}_att_dropout".format(i))(
        attention_output
    )
    attention_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}_att_layernormalization".format(i)
    )(query + attention_output)

    # Feed-forward layer
    ffn = keras.Sequential(
        [
            layers.Dense(config.FF_DIM, activation="relu"),
            layers.Dense(config.EMBED_DIM),
        ],
        name="encoder_{}_ffn".format(i),
    )
    ffn_output = ffn(attention_output)
    ffn_output = layers.Dropout(0.1, name="encoder_{}_ffn_dropout".format(i))(
        ffn_output
    )
    sequence_output = layers.LayerNormalization(
        epsilon=1e-6, name="encoder_{}_ffn_layernormalization".format(i)
    )(attention_output + ffn_output)
    return sequence_output


loss_fn = keras.losses.SparseCategoricalCrossentropy(reduction=None)
loss_tracker = keras.metrics.Mean(name="loss")


class MaskedLanguageModel(keras.Model):

    def compute_loss(self, x=None, y=None, y_pred=None, sample_weight=None):

        loss = loss_fn(y, y_pred, sample_weight)
        loss_tracker.update_state(loss, sample_weight=sample_weight)
        return keras.ops.sum(loss)

    def compute_metrics(self, x, y, y_pred, sample_weight):

        # Return a dict mapping metric names to current value
        return {"loss": loss_tracker.result()}

    @property
    def metrics(self):
        # We list our `Metric` objects here so that `reset_states()` can be
        # called automatically at the start of each epoch
        # or at the start of `evaluate()`.
        # If you don't implement this property, you have to call
        # `reset_states()` yourself at the time of your choosing.
        return [loss_tracker]


def create_masked_language_bert_model():
    inputs = layers.Input(shape=(config.MAX_LEN,), name="Input")
    
    word_embeddings = layers.Embedding(
        config.VOCAB_SIZE, 
        config.EMBED_DIM, 
        mask_zero=True, 
        name="word_embedding"
    )(inputs)
    position_embeddings = keras_hub.layers.PositionEmbedding(
        sequence_length=config.MAX_LEN,
        name="position_embedding"
    )(word_embeddings)
    embeddings = word_embeddings + position_embeddings

    encoder_output = embeddings
    for i in range(1, config.NUM_LAYERS+1):
        encoder_output = bert_module(encoder_output, encoder_output, encoder_output, i)

    mlm_output = layers.Dense(config.VOCAB_SIZE, name="mlm_cls", activation="softmax")(
        encoder_output
    )
    mlm_model = MaskedLanguageModel(inputs, mlm_output, name="masked_bert_model")

    optimizer = keras.optimizers.Adam(learning_rate=config.LR)
    mlm_model.compile(optimizer=optimizer)
    return mlm_model


id2token = dict(enumerate(vectorize_layer.get_vocabulary()))
token2id = {y: x for x, y in id2token.items()}


class MaskedTextGenerator(keras.callbacks.Callback):
    def __init__(self, sample_tokens, top_k=5):
        self.sample_tokens = sample_tokens
        self.k = top_k

    def decode(self, tokens):
        return " ".join([id2token[t] for t in tokens if t != 0])

    def convert_ids_to_tokens(self, id):
        return id2token[id]

    def on_epoch_end(self, epoch, logs=None):
        prediction = self.model.predict(self.sample_tokens)

        masked_index = np.where(self.sample_tokens == mask_token_id)
        masked_index = masked_index[1]
        mask_prediction = prediction[0][masked_index]

        top_indices = mask_prediction[0].argsort()[-self.k :][::-1]
        values = mask_prediction[0][top_indices]

        for i in range(len(top_indices)):
            p = top_indices[i]
            v = values[i]
            tokens = np.copy(sample_tokens[0])
            tokens[masked_index[0]] = p
            result = {
                "input_text": self.decode(sample_tokens[0].numpy()),
                "prediction": self.decode(tokens),
                "probability": v,
                "predicted mask token": self.convert_ids_to_tokens(p),
            }
            pprint(result)


sample_tokens = vectorize_layer(["Google wont [mask] replacing our news headlines with terrible AI"])

bert_masked_model = create_masked_language_bert_model()
bert_masked_model.summary()
# Out:
# Model: "masked_bert_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)  │ (None, 16)        │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ word_embedding      │ (None, 16, 128)   │  3,840,000 │ Input[0][0]       │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ position_embedding  │ (None, 16, 128)   │      2,048 │ word_embedding[0… │
# │ (PositionEmbedding) │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 128)   │          0 │ word_embedding[0… │
# │                     │                   │            │ position_embeddi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_multihea… │ (None, 16, 128)   │     66,048 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0],        │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_att_drop… │ (None, 16, 128)   │          0 │ encoder_1_multih… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 128)   │          0 │ add[0][0],        │
# │                     │                   │            │ encoder_1_att_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_att_laye… │ (None, 16, 128)   │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn       │ (None, 16, 128)   │    131,712 │ encoder_1_att_la… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn_drop… │ (None, 16, 128)   │          0 │ encoder_1_ffn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 128)   │          0 │ encoder_1_att_la… │
# │                     │                   │            │ encoder_1_ffn_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn_laye… │ (None, 16, 128)   │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_multihea… │ (None, 16, 128)   │     66,048 │ encoder_1_ffn_la… │
# │ (MultiHeadAttentio… │                   │            │ encoder_1_ffn_la… │
# │                     │                   │            │ encoder_1_ffn_la… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_att_drop… │ (None, 16, 128)   │          0 │ encoder_2_multih… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 128)   │          0 │ encoder_1_ffn_la… │
# │                     │                   │            │ encoder_2_att_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_att_laye… │ (None, 16, 128)   │        256 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn       │ (None, 16, 128)   │    131,712 │ encoder_2_att_la… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn_drop… │ (None, 16, 128)   │          0 │ encoder_2_ffn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 128)   │          0 │ encoder_2_att_la… │
# │                     │                   │            │ encoder_2_ffn_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn_laye… │ (None, 16, 128)   │        256 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mlm_cls (Dense)     │ (None, 16, 30000) │  3,870,000 │ encoder_2_ffn_la… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 8,108,592 (30.93 MB)
#  Trainable params: 8,108,592 (30.93 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
class MaskedTextGenerator(keras.callbacks.Callback):
    def __init__(self, sample_tokens, top_k=5):
        self.sample_tokens = sample_tokens
        self.k = top_k

    def decode(self, tokens):
        return " ".join([id2token[t] for t in tokens if t != 0])

    def convert_ids_to_tokens(self, id):
        return id2token[id]

    def on_epoch_end(self, epoch, logs=None):
        prediction = self.model.predict(self.sample_tokens)

        masked_index = np.where(self.sample_tokens == mask_token_id)
        masked_index = masked_index[1]
        mask_prediction = prediction[0][masked_index]

        top_indices = mask_prediction[0].argsort()[-self.k :][::-1]
        values = mask_prediction[0][top_indices]

        for i in range(len(top_indices)):
            p = top_indices[i]
            v = values[i]
            tokens = np.copy(sample_tokens[0])
            tokens[masked_index[0]] = p
            result = {
                "input_text": self.decode(sample_tokens[0].numpy()),
                "prediction": self.decode(tokens),
                "probability": v,
                "predicted mask token": self.convert_ids_to_tokens(p),
            }
            pprint(result)
generator_callback = MaskedTextGenerator(sample_tokens.numpy())

earlyStopping_callback = EarlyStopping(
    monitor="loss",
    min_delta=0.005,
    patience=5,
    verbose=0,
    mode="auto",
    baseline=None,
    restore_best_weights=True,
)

checkpoint_callback = ModelCheckpoint(
    os.path.join("models", "model_weights_cp_best.weights.h5"), 
    save_best_only=True,
    monitor="loss",
    save_weights_only=True,
    mode="min",
    verbose=1
)

# %%
def save_model_weights(model, file_name, folder_name):
    os.makedirs(folder_name, exist_ok=True)

    words = file_name.split(".")

    model_name = words[0]

    existing_files = [f for f in os.listdir(folder_name) if f.startswith(model_name)]
    next_number = len(existing_files) + 1
    words[0] = f"{model_name}_{next_number}"

    file_name = ".".join(words)
    save_path = os.path.join(folder_name, file_name)

    model.save_weights(save_path)
    print(f"model saved to: {save_path}")

# %%
# bert_masked_model.load_weights(os.path.join("models", "model_weights_cp_best.weights.h5"))
# bert_masked_model.fit(mlm_ds, epochs=50, callbacks=[generator_callback, checkpoint_callback, earlyStopping_callback])
# save_model_weights(bert_masked_model, "bert_masked_model_v2.weights.h5", "models")
# bert_masked_model.save("BERT_Pretrained.keras")

# %%
bert_masked_model = keras.models.load_model(
    os.path.join("models", "BERT_Pretrained.keras"), 
    custom_objects={"MaskedLanguageModel": MaskedLanguageModel}
)

# %%
bert_masked_model.summary()
# Out:
# Model: "masked_bert_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)  │ (None, 16)        │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ word_embedding      │ (None, 16, 128)   │  3,840,000 │ Input[0][0]       │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ position_embedding  │ (None, 16, 128)   │      2,048 │ word_embedding[0… │
# │ (PositionEmbedding) │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 128)   │          0 │ word_embedding[0… │
# │                     │                   │            │ position_embeddi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_multihea… │ (None, 16, 128)   │     66,048 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0],        │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_att_drop… │ (None, 16, 128)   │          0 │ encoder_1_multih… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 128)   │          0 │ add[0][0],        │
# │                     │                   │            │ encoder_1_att_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_att_laye… │ (None, 16, 128)   │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn       │ (None, 16, 128)   │    131,712 │ encoder_1_att_la… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn_drop… │ (None, 16, 128)   │          0 │ encoder_1_ffn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 128)   │          0 │ encoder_1_att_la… │
# │                     │                   │            │ encoder_1_ffn_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn_laye… │ (None, 16, 128)   │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_multihea… │ (None, 16, 128)   │     66,048 │ encoder_1_ffn_la… │
# │ (MultiHeadAttentio… │                   │            │ encoder_1_ffn_la… │
# │                     │                   │            │ encoder_1_ffn_la… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_att_drop… │ (None, 16, 128)   │          0 │ encoder_2_multih… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 128)   │          0 │ encoder_1_ffn_la… │
# │                     │                   │            │ encoder_2_att_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_att_laye… │ (None, 16, 128)   │        256 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn       │ (None, 16, 128)   │    131,712 │ encoder_2_att_la… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn_drop… │ (None, 16, 128)   │          0 │ encoder_2_ffn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 128)   │          0 │ encoder_2_att_la… │
# │                     │                   │            │ encoder_2_ffn_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn_laye… │ (None, 16, 128)   │        256 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ mlm_cls (Dense)     │ (None, 16, 30000) │  3,870,000 │ encoder_2_ffn_la… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,325,778 (92.80 MB)
#  Trainable params: 8,108,592 (30.93 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 16,217,186 (61.86 MB)

# %%
# Out:
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)  │ (None, 16)        │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ word_embedding      │ (None, 16, 128)   │  3,840,000 │ Input[0][0]       │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ position_embedding  │ (None, 16, 128)   │      2,048 │ word_embedding[0… │
# │ (PositionEmbedding) │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 128)   │          0 │ word_embedding[0… │
# │                     │                   │            │ position_embeddi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_multihea… │ (None, 16, 128)   │     66,048 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0],        │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_att_drop… │ (None, 16, 128)   │          0 │ encoder_1_multih… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 128)   │          0 │ add[0][0],        │
# │                     │                   │            │ encoder_1_att_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_att_laye… │ (None, 16, 128)   │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn       │ (None, 16, 128)   │    131,712 │ encoder_1_att_la… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn_drop… │ (None, 16, 128)   │          0 │ encoder_1_ffn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 128)   │          0 │ encoder_1_att_la… │
# │                     │                   │            │ encoder_1_ffn_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn_laye… │ (None, 16, 128)   │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_multihea… │ (None, 16, 128)   │     66,048 │ encoder_1_ffn_la… │
# │ (MultiHeadAttentio… │                   │            │ encoder_1_ffn_la… │
# │                     │                   │            │ encoder_1_ffn_la… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_att_drop… │ (None, 16, 128)   │          0 │ encoder_2_multih… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 128)   │          0 │ encoder_1_ffn_la… │
# │                     │                   │            │ encoder_2_att_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_att_laye… │ (None, 16, 128)   │        256 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn       │ (None, 16, 128)   │    131,712 │ encoder_2_att_la… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn_drop… │ (None, 16, 128)   │          0 │ encoder_2_ffn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 128)   │          0 │ encoder_2_att_la… │
# │                     │                   │            │ encoder_2_ffn_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn_laye… │ (None, 16, 128)   │        256 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,238,592 (16.17 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 4,238,592 (16.17 MB)

# %%
pretrained_bert_model = keras.Model(
    bert_masked_model.input, bert_masked_model.get_layer("encoder_2_ffn_layernormalization").output
)
pretrained_bert_model.trainable = False

pretrained_bert_model.summary()

def create_classifier_bert_model():
    inputs = layers.Input((config.MAX_LEN,), dtype="int64")
    sequence_output = pretrained_bert_model(inputs)
    
    pooled_output = layers.Lambda(lambda x: x[:, 0, :])(sequence_output)
    x = layers.BatchNormalization()(pooled_output)
    
    x = layers.Dense(128, activation="relu")(x)
    x = layers.BatchNormalization()(x) 
    x = layers.Dropout(0.3)(x)
    
    x = layers.Dense(64, activation="relu")(x)
    x = layers.BatchNormalization()(x)
    
    outputs = layers.Dense(3, activation="softmax")(x)

    classifier_model = Model(inputs, outputs, name="classification")
    
    optimizer = tf.keras.optimizers.Adam(learning_rate=2e-5) 
    
    classifier_model.compile(
        optimizer=optimizer, 
        loss="sparse_categorical_crossentropy", 
        metrics=["accuracy"]
    )
    return classifier_model


classifer_model = create_classifier_bert_model()
classifer_model.summary()

classifer_model.fit(
    train_classifier_ds,
    epochs=5,
    validation_data=test_classifier_ds,
)

pretrained_bert_model.trainable = True
optimizer = keras.optimizers.Adam()

classifer_model.compile(
    optimizer=optimizer, loss="sparse_categorical_crossentropy", metrics=["accuracy"]
)

classifer_model.fit(
    train_classifier_ds,
    epochs=5,
    validation_data=test_classifier_ds,
)
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)  │ (None, 16)        │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ word_embedding      │ (None, 16, 128)   │  3,840,000 │ Input[0][0]       │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ position_embedding  │ (None, 16, 128)   │      2,048 │ word_embedding[0… │
# │ (PositionEmbedding) │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 128)   │          0 │ word_embedding[0… │
# │                     │                   │            │ position_embeddi… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_multihea… │ (None, 16, 128)   │     66,048 │ add[0][0],        │
# │ (MultiHeadAttentio… │                   │            │ add[0][0],        │
# │                     │                   │            │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_att_drop… │ (None, 16, 128)   │          0 │ encoder_1_multih… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 128)   │          0 │ add[0][0],        │
# │                     │                   │            │ encoder_1_att_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_att_laye… │ (None, 16, 128)   │        256 │ add_1[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn       │ (None, 16, 128)   │    131,712 │ encoder_1_att_la… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn_drop… │ (None, 16, 128)   │          0 │ encoder_1_ffn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 16, 128)   │          0 │ encoder_1_att_la… │
# │                     │                   │            │ encoder_1_ffn_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_1_ffn_laye… │ (None, 16, 128)   │        256 │ add_2[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_multihea… │ (None, 16, 128)   │     66,048 │ encoder_1_ffn_la… │
# │ (MultiHeadAttentio… │                   │            │ encoder_1_ffn_la… │
# │                     │                   │            │ encoder_1_ffn_la… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_att_drop… │ (None, 16, 128)   │          0 │ encoder_2_multih… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 16, 128)   │          0 │ encoder_1_ffn_la… │
# │                     │                   │            │ encoder_2_att_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_att_laye… │ (None, 16, 128)   │        256 │ add_3[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn       │ (None, 16, 128)   │    131,712 │ encoder_2_att_la… │
# │ (Sequential)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn_drop… │ (None, 16, 128)   │          0 │ encoder_2_ffn[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 16, 128)   │          0 │ encoder_2_att_la… │
# │                     │                   │            │ encoder_2_ffn_dr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ encoder_2_ffn_laye… │ (None, 16, 128)   │        256 │ add_4[0][0]       │
# │ (LayerNormalizatio… │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 4,238,592 (16.17 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 4,238,592 (16.17 MB)
# Model: "classification"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 16)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ functional_9 (Functional)       │ (None, 16, 128)        │     4,238,592 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda_1 (Lambda)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 3)              │           195 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,264,835 (16.27 MB)
#  Trainable params: 25,603 (100.01 KB)
#  Non-trainable params: 4,239,232 (16.17 MB)
# Epoch 1/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.4348 - loss: 1.2411 - val_accuracy: 0.8317 - val_loss: 0.6802
# Epoch 2/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.8193 - loss: 0.4831 - val_accuracy: 0.8583 - val_loss: 0.4555
# Epoch 3/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9315 - loss: 0.2601 - val_accuracy: 0.8667 - val_loss: 0.4327
# Epoch 4/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9633 - loss: 0.1664 - val_accuracy: 0.8733 - val_loss: 0.4346
# Epoch 5/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9720 - loss: 0.1302 - val_accuracy: 0.8733 - val_loss: 0.4468
# Epoch 1/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9759 - loss: 0.0861 - val_accuracy: 0.8767 - val_loss: 0.7420
# Epoch 2/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9854 - loss: 0.0551 - val_accuracy: 0.8600 - val_loss: 0.8610
# Epoch 3/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9850 - loss: 0.0537 - val_accuracy: 0.8650 - val_loss: 0.7523
# Epoch 4/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 6s 34ms/step - accuracy: 0.9848 - loss: 0.0577 - val_accuracy: 0.8583 - val_loss: 0.7542
# Epoch 5/5
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9809 - loss: 0.0607 - val_accuracy: 0.8283 - val_loss: 1.1438

# %%
classifer_model.save_weights("March_Fifth_Final_model.weights.h5")

# %%
def predict(text, model):
    text_encoded = encode(text)
    # print("Encoded Text: ", text_encoded)
    
    pred = model(text_encoded, training=False)

    probabilities = tf.nn.softmax(pred, axis=-1).numpy()[0]

    pred_class = np.argmax(probabilities)
    sentiment = le.inverse_transform([pred_class])[0]
    confidence_score = probabilities[pred_class]

    class_names = le.classes_
    all_probs = {class_names[i]: float(probabilities[i]) for i in range(len(class_names))}
    
    return sentiment, confidence_score, all_probs

def predict_and_print(text, model):
    new_texts = [text]
    result, confidence, all_probs = predict(new_texts, model)
    
    print(f"Input Headline: \"{text}\"")
    print(f"Top Prediction: {result} ({confidence * 100:.2f}%)")
    print("-" * 30)
    print("Class Probabilities:")
    
    sorted_probs = sorted(all_probs.items(), key=lambda item: item[1], reverse=True)
    
    for label, prob in sorted_probs:
        bar = "#" * int(prob * 20) 
        print(f" - {label:<12}: {prob * 100:>6.2f}% {bar}")

    return result

# %%
test_headlines = [
    # 1. 명확한 부정 (Negative)
    "Apple shares plummet after disappointing iPhone sales report",
    "Lawsuit filed against Apple over battery throttling issues",
    "Supply chain disruptions expected to delay new Mac releases",
    
    # 2. 명확한 긍정 (Positive)
    "Apple's quarterly profit exceeds analyst expectations",
    "Revolutionary AI features announced for upcoming iOS update",
    "Warren Buffett increases stake in Apple, citing strong ecosystem",
    
    # 3. 중립 또는 단순 정보 (Neutral/Info)
    "Apple to hold its annual developer conference in June",
    "New software update available for Apple Watch users",
    "Tim Cook delivers keynote speech at university graduation",
    
    # 4. 모델을 시험하는 모호한 문장 (Edge Cases)
    "Apple is down today, but long-term outlook remains bright", # 부정+긍정 혼합
    "The new iPhone is not as bad as critics predicted",          # 이중 부정
    "Apple's competitor Samsung sees record-breaking growth",    # 경쟁사 소식 (애플에겐 위협?)
    "Is Apple losing its innovative edge?",                      # 의문문형 부정
]

# %%
for headline in test_headlines:
    predict_and_print(headline, classifer_model)
    print("\n" + "="*50 + "\n")
# Out:
# Input Headline: "Apple shares plummet after disappointing iPhone sales report"
# Top Prediction: negative (41.17%)
# ------------------------------
# Class Probabilities:
#  - negative    :  41.17% ########
#  - neutral     :  35.53% #######
#  - positive    :  23.30% ####
#
# ==================================================
#
# Input Headline: "Lawsuit filed against Apple over battery throttling issues"
# Top Prediction: neutral (48.43%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  48.43% #########
#  - negative    :  28.84% #####
#  - positive    :  22.72% ####
#
# ==================================================
#
# Input Headline: "Supply chain disruptions expected to delay new Mac releases"
# Top Prediction: neutral (57.59%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.59% ###########
#  - positive    :  21.21% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple's quarterly profit exceeds analyst expectations"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Revolutionary AI features announced for upcoming iOS update"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Warren Buffett increases stake in Apple, citing strong ecosystem"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple to hold its annual developer conference in June"
# Top Prediction: positive (41.07%)
# ------------------------------
# Class Probabilities:
#  - positive    :  41.07% ########
#  - neutral     :  35.42% #######
#  - negative    :  23.50% ####
#
# ==================================================
#
# Input Headline: "New software update available for Apple Watch users"
# Top Prediction: neutral (57.52%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.52% ###########
#  - positive    :  21.26% ####
#  - negative    :  21.22% ####
#
# ==================================================
#
# Input Headline: "Tim Cook delivers keynote speech at university graduation"
# Top Prediction: positive (57.29%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.29% ###########
#  - neutral     :  21.45% ####
#  - negative    :  21.27% ####
#
# ==================================================
#
# Input Headline: "Apple is down today, but long-term outlook remains bright"
# Top Prediction: negative (57.60%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.60% ###########
#  - neutral     :  21.20% ####
#  - positive    :  21.20% ####
#
# ==================================================
#
# Input Headline: "The new iPhone is not as bad as critics predicted"
# Top Prediction: neutral (54.71%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  54.71% ##########
#  - negative    :  23.45% ####
#  - positive    :  21.85% ####
#
# ==================================================
#
# Input Headline: "Apple's competitor Samsung sees record-breaking growth"
# Top Prediction: neutral (47.79%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  47.79% #########
#  - positive    :  28.30% #####
#  - negative    :  23.92% ####
#
# ==================================================
#
# Input Headline: "Is Apple losing its innovative edge?"
# Top Prediction: negative (56.50%)
# ------------------------------
# Class Probabilities:
#  - negative    :  56.50% ###########
#  - positive    :  22.06% ####
#  - neutral     :  21.44% ####
#
# ==================================================

# %%
gn = GoogleNews(lang = "en", country = "US")
google_news = gn.search('Apple', when='7d')

# %%
google_news
# Out:
# {'feed': {'generator_detail': {'name': 'NFE/5.0'},
#   'generator': 'NFE/5.0',
#   'title': '"Apple when:3d" - Google News',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': '',
#    'value': '"Apple when:3d" - Google News'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://news.google.com/search?q=Apple+when:3d&ceid=US:en&hl=en-US&gl=US'}],
#   'link': 'https://news.google.com/search?q=Apple+when:3d&ceid=US:en&hl=en-US&gl=US',
#   'language': 'en-US',
#   'publisher': 'news-webmaster@google.com',
#   'publisher_detail': {'email': 'news-webmaster@google.com'},
#   'rights': 'Copyright © 2026 Google. All rights reserved. This XML feed is made available solely for the purpose of rendering Google News results within a personal feed reader for personal, non-commercial use. Any other use of the feed is expressly prohibited. By accessing this feed or using these results in any manner whatsoever, you agree to be bound by the foregoing restrictions.',
#   'rights_detail': {'type': 'text/plain',
#    'language': None,
#    'base': '',
#    'value': 'Copyright © 2026 Google. All rights reserved. This XML feed is made available solely for the purpose of rendering Google News results within a personal feed reader for personal, non-commercial use. Any other use of the feed is expressly prohibited. By accessing this feed or using these results in any manner whatsoever, you agree to be bound by the foregoing restrictions.'},
#   'updated': 'Thu, 05 Mar 2026 17:46:20 GMT',
#   'updated_parsed': time.struct_time(tm_year=2026, tm_mon=3, tm_mday=5, tm_hour=17, tm_min=46, tm_sec=20, tm_wday=3, tm_yday=64, tm_isdst=0),
#   'image': {'title': 'Google News',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': '',
#     'value': 'Google News'},
#    'href': 'https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w256',
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://news.google.com/'}],
#    'link': 'https://news.google.com/',
#    'height': 256,
#    'width': 256},
#   'subtitle': 'Google News',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': '',
#    'value': 'Google News'}},
#  'entries': [{'title': 'MacBook Neo - Apple',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': '',
#     'value': 'MacBook Neo - Apple'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://news.google.com/rss/articles/CBMiSkFVX3lxTE0zUFJGcWw3TXRQekFfQUtKaXJCX3VEbUVIaGJYaE1QM09Lb2xFSjQ5OEY5Q1dXR2laTFRmY19XUEJCSjU2SGkxdWtR?oc=5'}],
#    'link': 'https://news.google.com/rss/articles/CBMiSkFVX3lxTE0zUFJGcWw3TXRQekFfQUtKaXJCX3VEbUVIaGJYaE1QM09Lb2xFSjQ5OEY5Q1dXR2laTFRmY19XUEJCSjU2SGkxdWtR?oc=5',
#    'id': 'CBMiSkFVX3lxTE0zUFJGcWw3TXRQekFfQUtKaXJCX3VEbUVIaGJYaE1QM09Lb2xFSjQ5OEY5Q1dXR2laTFRmY19XUEJCSjU2SGkxdWtR',
#    'guidislink': False,
#    'published': 'Thu, 05 Mar 2026
font>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': '',
#     'value': '<a href="https://news.google.com/rss/articles/CBMikgFBVV95cUxOUV94TmVpcFJmdzRCRVYwOF9ZQ0YtSXdreGVkRFpPTG93cExWWW9MMnpzWk1QUmVHblZ2N19jTnpxclNXVzVXRFpudHM1Z0U3Z0hnemVfa05fOW1kSWlTWkp0SzFWd3BtTC1TRzJnYkRhMUZKekZ6dEVUVTNoOXlyM1puVGhtdVZ5dVdueXJfNVhJdw?oc=5" target="_blank">Why MacBook Neo is Apple’s best new model for most people</a>&nbsp;&nbsp;<font color="#6f6f6f">9to5Mac</font>'},
#    'source': {'href': 'https://9to5mac.com', 'title': '9to5Mac'},
#    'sub_articles': []},
#   {'title': 'Apple’s M5 MacBook Air Is Now Up for Pre-Order, Even Cheaper Than Older Microsoft Surface Laptops - Gizmodo',
#    'title_detail': {'type': 'text/plain',
#     'language': None,
#     'base': '',
#     'value': 'Apple’s M5 MacBook Air Is Now Up for Pre-Order, Even Cheaper Than Older Microsoft Surface Laptops - Gizmodo'},
#    'links': [{'rel': 'alternate',
#      'type': 'text/html',
#      'href': 'https://news.google.?oc=5'}],
#    'link': 'https://news.google.?oc=5',
#    'id': '',
#    'guidislink': False,
#    'published': 'Thu, 05 Mar 2026 14:35:38 GMT',
#    'published_parsed': time.struct_time(tm_year=2026, tm_mon=3, tm_mday=5, tm_hour=14, tm_min=35, tm_sec=38, tm_wday=3, tm_yday=64, tm_isdst=0),
#    'summary': '<a href="https://news.google.?oc=5" target="_blank">Apple’s M5 MacBook Air Is Now Up for Pre-Order, Even Cheaper Than Older Microsoft Surface Laptops</a>&nbsp;&nbsp;<font color="#6f6f6f">Gizmodo</font>',
#    'summary_detail': {'type': 'text/html',
#     'language': None,
#     'base': '',
#     'value': '<a href="https://news.google.?oc=5" target="_blank">Apple’s M5 MacBook Air Is Now Up for Pre-Order, Even Cheaper Than Older Microsoft Surface Laptops</a>&nbsp;&nbsp;<font color="#6f6f6f">Gizmodo</font>'},
#    'source': {'href': 'https://gizmodo.com', 'title': 'Gizmodo'},
#    'sub_articles': []}]}

# %%
for entry in google_news['entries']:
    print(entry['title'])
# Out:
# MacBook Neo - Apple
# The MacBook Neo and Everything Else Apple Announced This Week - IGN
# New Apple TV and HomePod Mini Are Still Missing, Here's Why - MacRumors
# Apple reveal details of F1 integration on Apple TV, Apple Maps, Apple News and more - Formula 1
# iPad or MacBook Neo? Comparing Apple’s three $600 computers - 9to5Mac
# Why Apple Pie From A Bakery Always Tastes Better Than Homemade - Chowhound
# My patience did not pay off – no new Apple TV 4K announced at Apple's "Special Experience" - What Hi-Fi?
# Apple Launches 6 New Products, Discontinues 7—See the Full List - Newsweek
# Apple's New MacBook Neo Offers Affordability At $599 For Budget-savvy Consumers - 101.5 WPDH
# Apple Releases iOS 26.3.1: Critical iPhone Update With New Features And Fixes - Forbes
# How to Watch: Charlotte FC vs Austin FC | 7:30 PM | Apple TV - Charlotte FC
# Apple explains why its cheapest MacBook is called 'Neo' - TweakTown
# The Bargain-Basement MacBook Neo Exposes the Insane Price of Another Key Apple Product - WIRED
# The 2026 Formula 1® season begins this weekend, exclusively on Apple TV in the U.S. - Apple
# Say hello to MacBook Neo - Apple
# Apple TV debuts trailer for season two of “Your Friends & Neighbors” - Apple
# Apple introduces MacBook Pro with all-new M5 Pro and M5 Max - Apple
# Apple introduces the new MacBook Air with M5 - Apple
# Ford Racing to Stream Storytelling Ads on Apple TV - Autoweek
# Apple Music Introduces ‘Transparency Tags’ To Flag AI-Generated Music And Artwork - Forbes
# Apple has one more release this week: OS 26.3.1 is here - Macworld
# Apple’s $5 Trillion March: Why the Gemini Partnership is the “Golden Goose” for 2026 - Yahoo Finance
# John Ternus talks Apple CEO speculation, MacBook Neo, more - 9to5Mac
# Apple’s new 2026 MacBook Neo laptop is surprisingly cheap at Walmart & Amazon - NJ.com
# Apple's $599 Macbook Neo launch leaves social media with questions - Indy100
# Why Apple Decided the Time Was Right for a $599 MacBook - Bloomberg.com
# “The magic of the Mac at a breakthrough price”: Apple’s new MacBook Neo might be cheap, but for music producers, could it be a false economy? It’s complicated - MusicRadar
# Forget Chromebooks and Pre-Order the MacBook Neo, Apple’s Cheapest Laptop Yet in Colorful Finishes - Gizmodo
# Apple's MacBook Neo comes in citrus yellow and blush pink. The internet has thoughts. - Mashable
# Apple Unveils MacBook Neo, Starting at $599 - eurweb.com
# A new cheaper MacBook just dropped — here’s everything you need to know - NBC News
# Preorders for Apple’s colorful MacBook Neo come with a $25 gift card - The Verge
# Apple’s $5 Trillion March: Why the Gemini Partnership is the "Golden Goose" for 2026 - 24/7 Wall St.
# Apple's lo-fi MacBook Neo gets an iPhone chip and a tempting price tag - New Atlas
# Apple's Piss-Colored MacBook Neo Is My Ideal Budget Laptop - Kotaku
# If You Prefer Apple Over Samsung, Pre-Order the iPhone 17e for Less With Trade-In - Gizmodo
# Attention, Severance Fans: Apple TV Considering Prequel, Spinoff and More Possible Series - SYFY
# I Tried the New iPhone 17e in London. This Budget Beast Has the Brains of a Flagship - PCMag
# Apple's iOS 26.3.1 Brings Bug Fixes, Studio Display Support - CNET
# Apple's Biggest Week of 2026: Details on Every New Product Announced - MacRumors
# Apple Music Rolling Out Disclosure Tags for AI-Made Songs - MacRumors
# Apple Magic Mouse Drops to Its Lowest Price Ever Following the New MacBook and Studio Display Launch - Gizmodo
# Apple Does Not Include a Charger With All New MacBooks in UK and EU - MacRumors
# Does Apple Have a New Hit Product? I Think So! - The Motley Fool
# Apple launches first-ever budget MacBook - Dezeen
# Apple announces MacBook Neo, its most affordable laptop ever - CNBC
# This iPad is now under $100 - Boing Boing
# Apple Music Rolls Out Voluntary AI Transparency Tags - The Tech Buzz
# The $599 iPhone 17e looks like the budget iPhone we really want - CNN
# Apple Music Doesn’t Want to Trick You With AI Songs - Vulture
# The MacBook NEO is available at Walmart for preorder - Price begins at $599 - Syracuse.com
# WIU art education student joins Golden Apple teaching program - Galesburg Register Mail
# Apple was quietly all over the world's biggest Android phone show, and that says a lot - ZDNET
# Experience Hopewell’s Beloved Apple Orchard - Berks Community Television
# Deals: MacBook Neo, MacBook Air up to $300 off, rare iPhone Air price drop, Apple Watch bands from $14, more - 9to5Mac
# Today's Apple TV deals up to 85% off: The Hobbit Extended Trilogy, Joker, Apocalypse Now Collection, more - 9to5Toys
# Why MacBook Neo is Apple’s best new model for most people - 9to5Mac
# Apple’s M5 MacBook Air Is Now Up for Pre-Order, Even Cheaper Than Older Microsoft Surface Laptops - Gizmodo

# %%
len(google_news['entries'])
# Out:
# 100

# %%
positive_count = 0
negative_count = 0
neutral_count = 0

for entry in google_news['entries']:
    result = predict_and_print(entry['title'], classifer_model)
    if result is not None:
        if ("positive" in result):
            positive_count += 1
        elif ("negative" in result):
            negative_count += 1
        elif ("neutral" in result):
            neutral_count += 1

    print("\n" + "="*50 + "\n")

print(f"Positive Count: {positive_count}")
print(f"Negative Count: {negative_count}")
print(f"Neutral Count: {neutral_count}")
# Out:
# Input Headline: "Apple introduces iPhone 17e - Apple"
# Top Prediction: positive (55.62%)
# ------------------------------
# Class Probabilities:
#  - positive    :  55.62% ###########
#  - neutral     :  22.76% ####
#  - negative    :  21.62% ####
#
# ==================================================
#
# Input Headline: "I Wore an Apple Watch and Oura Ring for Months. Here's the One I Actually Kept - CNET"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "I’m most excited about Apple’s affordable MacBook, with one concern - 9to5Mac"
# Top Prediction: positive (45.88%)
# ------------------------------
# Class Probabilities:
#  - positive    :  45.88% #########
#  - negative    :  31.08% ######
#  - neutral     :  23.04% ####
#
# ==================================================
#
# Input Headline: "Apple Is in Its Affordable Era. Sort Of. - The New York Times"
# Top Prediction: neutral (57.57%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.57% ###########
#  - positive    :  21.22% ####
#  - negative    :  21.21% ####
#
# ==================================================
#
# Input Headline: "MacBook Neo hands-on: Apple build quality at a substantially lower price - Ars Technica"
# Top Prediction: negative (57.60%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.60% ###########
#  - neutral     :  21.20% ####
#  - positive    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple raises MacBook prices across the board as M5 chips, new displays signal AI-first strategy - CNBC"
# Top Prediction: positive (57.58%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.58% ###########
#  - neutral     :  21.22% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "A new cheaper MacBook just dropped — here’s everything you need to know - NBC News"
# Top Prediction: negative (57.58%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.58% ###########
#  - neutral     :  21.21% ####
#  - positive    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple debuts $599 iPhone 17e, more powerful iPad Airs - Yahoo Finance"
# Top Prediction: positive (57.59%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.59% ###########
#  - neutral     :  21.21% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "7 Apple Releases You May Have Missed This Week - Gear Patrol"
# Top Prediction: positive (57.60%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.60% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Charting the vibes in the 2025 Apple Report Card - Six Colors"
# Top Prediction: positive (50.94%)
# ------------------------------
# Class Probabilities:
#  - positive    :  50.94% ##########
#  - neutral     :  26.68% #####
#  - negative    :  22.39% ####
#
# ==================================================
#
# Input Headline: "Say hello to MacBook Neo - Apple"
# Top Prediction: positive (42.63%)
# ------------------------------
# Class Probabilities:
#  - positive    :  42.63% ########
#  - neutral     :  33.98% ######
#  - negative    :  23.39% ####
#
# ==================================================
#
# Input Headline: "Apple launches lower cost iPhone 17e and a new iPad Air powered by its M4 chip - CNBC"
# Top Prediction: negative (57.51%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.51% ###########
#  - neutral     :  21.25% ####
#  - positive    :  21.24% ####
#
# ==================================================
#
# Input Headline: "iPhone and iPad approved to handle classified NATO information - Apple"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple unveils new Studio Display and all-new Studio Display XDR - Apple"
# Top Prediction: positive (57.54%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.54% ###########
#  - neutral     :  21.25% ####
#  - negative    :  21.21% ####
#
# ==================================================
#
# Input Headline: "Apple introduces the new iPad Air, powered by M4 - Apple"
# Top Prediction: neutral (55.27%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  55.27% ###########
#  - positive    :  23.05% ####
#  - negative    :  21.68% ####
#
# ==================================================
#
# Input Headline: "Apple introduces MacBook Pro with all-new M5 Pro and M5 Max - Apple"
# Top Prediction: positive (57.51%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.51% ###########
#  - neutral     :  21.27% ####
#  - negative    :  21.22% ####
#
# ==================================================
#
# Input Headline: "Apple introduces the new MacBook Air with M5 - Apple"
# Top Prediction: neutral (56.60%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  56.60% ###########
#  - positive    :  21.98% ####
#  - negative    :  21.42% ####
#
# ==================================================
#
# Input Headline: "Apple debuts M5 Pro and M5 Max to supercharge the most demanding pro workflows - Apple"
# Top Prediction: negative (38.56%)
# ------------------------------
# Class Probabilities:
#  - negative    :  38.56% #######
#  - positive    :  38.10% #######
#  - neutral     :  23.33% ####
#
# ==================================================
#
# Input Headline: "MacBook Neo - Apple"
# Top Prediction: neutral (57.54%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.54% ###########
#  - positive    :  21.24% ####
#  - negative    :  21.22% ####
#
# ==================================================
#
# Input Headline: "The 2026 Formula 1® season begins this weekend, exclusively on Apple TV in the U.S. - Apple"
# Top Prediction: negative (57.45%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.45% ###########
#  - neutral     :  21.31% ####
#  - positive    :  21.24% ####
#
# ==================================================
#
# Input Headline: "Apple announces MacBook Neo, its most affordable laptop ever - CNBC"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "You Can’t Stop the Growth of Knowledge: Interview with Ronald Wayne, Co-Founder of Apple - Adam Mendler"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple launches cheaper iPhone 17e in push to boost iPhone sales - CNN"
# Top Prediction: positive (57.59%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.59% ###########
#  - neutral     :  21.21% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple Just Released a Slew of Products Under $1,000 - Esquire"
# Top Prediction: positive (56.12%)
# ------------------------------
# Class Probabilities:
#  - positive    :  56.12% ###########
#  - neutral     :  22.38% ####
#  - negative    :  21.50% ####
#
# ==================================================
#
# Input Headline: "The $599 iPhone 17e looks like the budget iPhone we really want - CNN"
# Top Prediction: positive (53.00%)
# ------------------------------
# Class Probabilities:
#  - positive    :  53.00% ##########
#  - neutral     :  24.94% ####
#  - negative    :  22.06% ####
#
# ==================================================
#
# Input Headline: "Apple's March 4 Event Is Almost Here. 5 Things on My Wishlist - PCMag"
# Top Prediction: positive (39.52%)
# ------------------------------
# Class Probabilities:
#  - positive    :  39.52% #######
#  - neutral     :  37.20% #######
#  - negative    :  23.28% ####
#
# ==================================================
#
# Input Headline: "Apple Announces New iPhone and iPad Air as Week of Launches Begins - Barron's"
# Top Prediction: positive (57.56%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.56% ###########
#  - neutral     :  21.23% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple’s March event: 6 burning questions - Macworld"
# Top Prediction: negative (57.56%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.56% ###########
#  - neutral     :  21.23% ####
#  - positive    :  21.21% ####
#
# ==================================================
#
# Input Headline: "Apple’s Touch MacBook Will Stop Well Short of a Mac-iPad Hybrid - Bloomberg.com"
# Top Prediction: neutral (57.43%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.43% ###########
#  - positive    :  21.31% ####
#  - negative    :  21.26% ####
#
# ==================================================
#
# Input Headline: "Apple Updated the Wrong iPad - CNET"
# Top Prediction: neutral (57.59%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.59% ###########
#  - positive    :  21.21% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple announces new iPhone 17e, its $599 budget smartphone - Mashable"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "The Colorful MacBook Neo Is Apple’s Cheapest Laptop Ever - WIRED"
# Top Prediction: neutral (57.59%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.59% ###########
#  - positive    :  21.21% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple’s March announcements aren’t even close to done - Macworld"
# Top Prediction: neutral (57.44%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.44% ###########
#  - negative    :  21.28% ####
#  - positive    :  21.28% ####
#
# ==================================================
#
# Input Headline: "Apple Discusses Google Hosting New Siri as Need for Cloud Help Grows - The Information"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "The $599 Apple MacBook Neo is the laptop I’ve been waiting for - CNN"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple testing a Studio Display with high-end ports and speakers - Macworld"
# Top Prediction: positive (57.57%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.57% ###########
#  - neutral     :  21.22% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple’s New MacBook Air and MacBook Pro Have New Chips, More Storage, and Higher Prices - WIRED"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple makes a Trojan horse play for the education market - Six Colors"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - negative    :  21.20% ####
#  - neutral     :  21.20% ####
#
# ==================================================
#
# Input Headline: "Three ways new Apple products next week will modernize iPhone, iPad, and Mac - 9to5Mac"
# Top Prediction: positive (43.98%)
# ------------------------------
# Class Probabilities:
#  - positive    :  43.98% ########
#  - neutral     :  32.91% ######
#  - negative    :  23.11% ####
#
# ==================================================
#
# Input Headline: "Apple’s MacBook Neo is $599? Whoa. - Macworld"
# Top Prediction: neutral (57.37%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.37% ###########
#  - positive    :  21.37% ####
#  - negative    :  21.26% ####
#
# ==================================================
#
# Input Headline: "Whoops! Apple accidentally reveals ‘MacBook Neo’ - Macworld"
# Top Prediction: negative (53.63%)
# ------------------------------
# Class Probabilities:
#  - negative    :  53.63% ##########
#  - neutral     :  23.90% ####
#  - positive    :  22.47% ####
#
# ==================================================
#
# Input Headline: "Apple launches iPhone 17e at $599, boosts base storage to 256 gigabytes - Reuters"
# Top Prediction: neutral (57.56%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.56% ###########
#  - positive    :  21.23% ####
#  - negative    :  21.21% ####
#
# ==================================================
#
# Input Headline: "Everything you need to know about Apple's 'big week' of product launches - ABC News"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Everything Apple announced this week: iPhone 17e, new MacBooks, M4 iPad Air and more - Engadget"
# Top Prediction: positive (57.33%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.33% ###########
#  - neutral     :  21.41% ####
#  - negative    :  21.25% ####
#
# ==================================================
#
# Input Headline: "Apple has one more release this week: OS 26.3.1 is here - Macworld"
# Top Prediction: positive (57.44%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.44% ###########
#  - neutral     :  21.33% ####
#  - negative    :  21.23% ####
#
# ==================================================
#
# Input Headline: "Apple reveal details of F1 integration on Apple TV, Apple Maps, Apple News and more - Formula 1"
# Top Prediction: positive (57.46%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.46% ###########
#  - neutral     :  21.31% ####
#  - negative    :  21.23% ####
#
# ==================================================
#
# Input Headline: "Apple debuts $599 MacBook Neo to challenge Chromebooks, Windows PCs - Reuters"
# Top Prediction: neutral (57.55%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.55% ###########
#  - positive    :  21.23% ####
#  - negative    :  21.21% ####
#
# ==================================================
#
# Input Headline: "Apple gives in to temptation and renames its CPU cores - Six Colors"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple announces its cheapest-ever new MacBook - CNN"
# Top Prediction: positive (57.60%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.60% ###########
#  - neutral     :  21.21% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Here are Apple’s updated trade-in values for March 2026 - 9to5Mac"
# Top Prediction: neutral (57.58%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.58% ###########
#  - positive    :  21.21% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple's MacBook Neo has a great price, but you need to take a close look at those specs - Mashable"
# Top Prediction: positive (52.88%)
# ------------------------------
# Class Probabilities:
#  - positive    :  52.88% ##########
#  - negative    :  25.03% #####
#  - neutral     :  22.09% ####
#
# ==================================================
#
# Input Headline: "Apple’s Budget iPhone 17e Gets a MagSafe Upgrade - WIRED"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple’s New MacBook Air And Pro Lineups Are More Expensive Than Ever - Forbes"
# Top Prediction: neutral (42.29%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  42.29% ########
#  - positive    :  34.51% ######
#  - negative    :  23.20% ####
#
# ==================================================
#
# Input Headline: "Apple’s ‘big week’ promises a great deal of not very much - Macworld"
# Top Prediction: positive (57.60%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.60% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple’s cheap MacBook only has one job - Macworld"
# Top Prediction: negative (57.54%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.54% ###########
#  - neutral     :  21.24% ####
#  - positive    :  21.22% ####
#
# ==================================================
#
# Input Headline: "Apple updates the iPad Air with an M4 chip - Engadget"
# Top Prediction: positive (57.50%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.50% ###########
#  - negative    :  21.25% ####
#  - neutral     :  21.25% ####
#
# ==================================================
#
# Input Headline: "Apple has discontinued seven products this week, with one more likely - 9to5Mac"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple debuts $599 MacBook Neo, targeting schools and small businesses - Yahoo Finance"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple Dubai Stores Closed Amid Ongoing Attacks From Iran - Forbes"
# Top Prediction: negative (57.58%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.58% ###########
#  - neutral     :  21.22% ####
#  - positive    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple Music to add Transparency Tags to distinguish AI music, says report - TechCrunch"
# Top Prediction: positive (57.60%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.60% ###########
#  - negative    :  21.20% ####
#  - neutral     :  21.20% ####
#
# ==================================================
#
# Input Headline: "It's high time I avenged my girdled apple trees - Agweek"
# Top Prediction: neutral (57.52%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.52% ###########
#  - positive    :  21.26% ####
#  - negative    :  21.22% ####
#
# ==================================================
#
# Input Headline: "Apple iPhone 17e vs. iPhone 17: Is the Cheaper Model Actually the Smarter Buy? - PCMag"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "A cheap MacBook is the perfect way for Apple to win over Windows users - Engadget"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple announces F1 details, and a surprising Netflix partnership - Six Colors"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Everything Apple announced today: iPhone 17e and M4 iPad Air - Engadget"
# Top Prediction: neutral (55.45%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  55.45% ###########
#  - positive    :  22.91% ####
#  - negative    :  21.64% ####
#
# ==================================================
#
# Input Headline: "Everything Apple announced this week: MacBook Neo, iPhone 17e and more - Engadget"
# Top Prediction: positive (56.96%)
# ------------------------------
# Class Probabilities:
#  - positive    :  56.96% ###########
#  - neutral     :  21.71% ####
#  - negative    :  21.33% ####
#
# ==================================================
#
# Input Headline: "Apple launches new MacBook Air and MacBook Pro with new M5 chips - Yahoo Finance"
# Top Prediction: neutral (57.53%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.53% ###########
#  - positive    :  21.26% ####
#  - negative    :  21.22% ####
#
# ==================================================
#
# Input Headline: "The MacBook Neo is Apple’s take on the Nike Dunk - Fast Company"
# Top Prediction: neutral (39.29%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  39.29% #######
#  - positive    :  37.15% #######
#  - negative    :  23.56% ####
#
# ==================================================
#
# Input Headline: "Apple’s first mini-LED ProMotion monitor has a nice price - Macworld"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple’s cheapest AirPods have hit $89 - The Verge"
# Top Prediction: neutral (57.59%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.59% ###########
#  - positive    :  21.21% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "The $599 MacBook Neo is Apple’s long-awaited colorful, lower-cost MacBook - Ars Technica"
# Top Prediction: neutral (57.40%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.40% ###########
#  - positive    :  21.34% ####
#  - negative    :  21.25% ####
#
# ==================================================
#
# Input Headline: "Some Apple AI servers are reportedly sitting unused on warehouse shelves, due to low Apple Intelligence usage - 9to5Mac"
# Top Prediction: negative (57.55%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.55% ###########
#  - neutral     :  21.23% ####
#  - positive    :  21.22% ####
#
# ==================================================
#
# Input Headline: "Apple unveils new MacBook Air and MacBook Pro with M5 - TechCrunch"
# Top Prediction: positive (52.92%)
# ------------------------------
# Class Probabilities:
#  - positive    :  52.92% ##########
#  - neutral     :  25.00% #####
#  - negative    :  22.08% ####
#
# ==================================================
#
# Input Headline: "MacBook Neo, iPhone 17e, and everything else Apple announced this week - TechCrunch"
# Top Prediction: neutral (57.54%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.54% ###########
#  - positive    :  21.24% ####
#  - negative    :  21.21% ####
#
# ==================================================
#
# Input Headline: "Apple store down ahead of MacBook Neo announcement - 9to5Mac"
# Top Prediction: negative (57.60%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.60% ###########
#  - neutral     :  21.20% ####
#  - positive    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple’s new Studio Displays come with Thunderbolt 5 - TechCrunch"
# Top Prediction: positive (50.20%)
# ------------------------------
# Class Probabilities:
#  - positive    :  50.20% ##########
#  - neutral     :  27.29% #####
#  - negative    :  22.50% ####
#
# ==================================================
#
# Input Headline: "How Taco Bell is becoming the Apple of fast food - Fast Company"
# Top Prediction: positive (42.17%)
# ------------------------------
# Class Probabilities:
#  - positive    :  42.17% ########
#  - neutral     :  34.63% ######
#  - negative    :  23.20% ####
#
# ==================================================
#
# Input Headline: "10 things to know about Apple’s new M5 Pro and M5 Max MacBook Pros - Popular Science"
# Top Prediction: neutral (57.14%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.14% ###########
#  - positive    :  21.56% ####
#  - negative    :  21.30% ####
#
# ==================================================
#
# Input Headline: "Apple is launching new products this week, here’s what’s coming - 9to5Mac"
# Top Prediction: neutral (57.59%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.59% ###########
#  - positive    :  21.21% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple says it has “a big week ahead.” Here’s what we expect to see. - Ars Technica"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple unveils lower cost iPhone 17e, raises prices on MacBooks - Fox Business"
# Top Prediction: negative (57.59%)
# ------------------------------
# Class Probabilities:
#  - negative    :  57.59% ###########
#  - neutral     :  21.21% ####
#  - positive    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple bakes in AI smarts into its new $599 iPhone 17e - TechCrunch"
# Top Prediction: positive (56.41%)
# ------------------------------
# Class Probabilities:
#  - positive    :  56.41% ###########
#  - neutral     :  22.15% ####
#  - negative    :  21.44% ####
#
# ==================================================
#
# Input Headline: "Apple's Piss-Colored MacBook Neo Is My Ideal Budget Laptop - Kotaku"
# Top Prediction: positive (57.60%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.60% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "AI Disruption: Why Apple, Coke, and Other Consumer Stocks Could Hold Up Better Than Software - Barron's"
# Top Prediction: positive (57.08%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.08% ###########
#  - neutral     :  21.61% ####
#  - negative    :  21.31% ####
#
# ==================================================
#
# Input Headline: "Apple Launches $599 MacBook Neo, Threatening Windows PC Market - Bloomberg.com"
# Top Prediction: neutral (57.14%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.14% ###########
#  - negative    :  21.52% ####
#  - positive    :  21.35% ####
#
# ==================================================
#
# Input Headline: "Apple closes all stores in fast-growing market - thestreet.com"
# Top Prediction: neutral (57.53%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.53% ###########
#  - positive    :  21.24% ####
#  - negative    :  21.22% ####
#
# ==================================================
#
# Input Headline: "Apple’s low-cost MacBook may skip some features you won’t miss - Macworld"
# Top Prediction: neutral (57.51%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.51% ###########
#  - positive    :  21.26% ####
#  - negative    :  21.22% ####
#
# ==================================================
#
# Input Headline: "Apple just dropped 6 new products. What are they? - USA Today"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - negative    :  21.20% ####
#  - neutral     :  21.20% ####
#
# ==================================================
#
# Input Headline: "Apple debuts its 2026 spring accessory collection for iPhone and Apple Watch - 9to5Mac"
# Top Prediction: neutral (49.01%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  49.01% #########
#  - positive    :  28.23% #####
#  - negative    :  22.76% ####
#
# ==================================================
#
# Input Headline: "The MacBook Neo May Be Apple’s Most Consequential New Product in a Decade - inc.com"
# Top Prediction: neutral (56.87%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  56.87% ###########
#  - positive    :  21.77% ####
#  - negative    :  21.36% ####
#
# ==================================================
#
# Input Headline: "Apple’s new products add C1X chip for three unique advantages - 9to5Mac"
# Top Prediction: positive (55.83%)
# ------------------------------
# Class Probabilities:
#  - positive    :  55.83% ###########
#  - neutral     :  22.61% ####
#  - negative    :  21.56% ####
#
# ==================================================
#
# Input Headline: "Apple launches new generation of Studio Display - 9to5Mac"
# Top Prediction: neutral (57.60%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.60% ###########
#  - positive    :  21.20% ####
#  - negative    :  21.20% ####
#
# ==================================================
#
# Input Headline: "Meet the MacBook Neo, Apple’s colorful answer to the Chromebook, starting at $599 - TechCrunch"
# Top Prediction: negative (56.98%)
# ------------------------------
# Class Probabilities:
#  - negative    :  56.98% ###########
#  - neutral     :  21.64% ####
#  - positive    :  21.38% ####
#
# ==================================================
#
# Input Headline: "Apple's Colorful $599 MacBook Neo Is Here, Runs A18 Pro Mobile Chip - PCMag"
# Top Prediction: neutral (56.33%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  56.33% ###########
#  - positive    :  22.20% ####
#  - negative    :  21.48% ####
#
# ==================================================
#
# Input Headline: "Apple iPhone 18 Pro Design Changes Come Into Focus In New Leaks - Forbes"
# Top Prediction: neutral (57.33%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.33% ###########
#  - positive    :  21.39% ####
#  - negative    :  21.28% ####
#
# ==================================================
#
# Input Headline: "Apple announces the iPhone 17E - The Verge"
# Top Prediction: positive (57.61%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.61% ###########
#  - neutral     :  21.20% ####
#  - negative    :  21.19% ####
#
# ==================================================
#
# Input Headline: "Apple’s rumored MacBook Neo, a lower-cost, colorful laptop, could launch this week - TechCrunch"
# Top Prediction: neutral (42.18%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  42.18% ########
#  - positive    :  34.59% ######
#  - negative    :  23.23% ####
#
# ==================================================
#
# Input Headline: "Apple’s higher (and lower) MacBook pricing explained - Macworld"
# Top Prediction: positive (57.37%)
# ------------------------------
# Class Probabilities:
#  - positive    :  57.37% ###########
#  - negative    :  21.38% ####
#  - neutral     :  21.25% ####
#
# ==================================================
#
# Input Headline: "Apple Music Coming to Chocolate Bars - MacRumors"
# Top Prediction: neutral (56.80%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  56.80% ###########
#  - negative    :  21.72% ####
#  - positive    :  21.48% ####
#
# ==================================================
#
# Input Headline: "Apple introduces the $599 iPhone 17e with MagSafe and twice the storage - Engadget"
# Top Prediction: neutral (57.45%)
# ------------------------------
# Class Probabilities:
#  - neutral     :  57.45% ###########
#  - positive    :  21.32% ####
#  - negative    :  21.24% ####
#
# ==================================================
#
# Positive Count: 0
# Negative Count: 0
# Neutral Count: 0
